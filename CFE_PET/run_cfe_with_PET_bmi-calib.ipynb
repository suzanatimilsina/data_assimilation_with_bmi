# %%
# !pip install eto
import os
import time
import numpy as np
import pandas as pd
import json
import matplotlib.pyplot as plt
import bmi_cfe
import bmi_PET
from fao_pet import ETRCalculator
import matplotlib.pyplot as plt
from bmi_cfe import BMI_CFE

# %%
import os
import time
import numpy as np
import pandas as pd
import json
import matplotlib.pyplot as plt
from bmi_cfe import BMI_CFE

# %%
# input_dir = './wb-2624577_oct/json_input_config'   # One value is calibrated
input_dir = './wb-2624577_retro_3_2022/json_input_config'
forcing_dir = './wb-2624577_retro_3_2022/forcings/'
output_dir = './wb-2624577_retro_3_2022/outputs'

# %%
# input_dir = './Carmel_inputs_January_2017/pet_config'
# forcing_dir = './Carmel_inputs_January_2017/forcings'
# # output_dir = './output_dir/cfe_output_2017'
# output_dir = './Carmel_inputs_January_2017/output_decjanfeb'

# %%
# pip install dataretrieval

# %%
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# %% [markdown]
# # 1. Run Normal CFE Simulations

# %%
# istart_plot = 0
# iend_plot = 550
# x = list(range(istart_plot, iend_plot))
# for output in outputs:
#     plt.plot(x, output_lists[output][istart_plot:iend_plot], label=output)
#     plt.title(output)
#     plt.legend()
#     plt.show()
#     plt.close()

# %%
import os
import json
import pandas as pd

# Check if output directory exists, if not, create it
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# Iterate over all files in input_dir
for filename in os.listdir(input_dir):
    if filename.endswith(".json"):  # check if the file is a JSON file
        file_path = os.path.join(input_dir, filename)
        filename_without_extension = os.path.splitext(os.path.basename(file_path))[0]
        # Initialize CFE instance
        cfe_instance = BMI_CFE(file_path)
        cfe_instance.initialize()
        
# If PET is added through BMI then use the pet_instance. Currently set to 0 to check the model and explore other PET methods 

        # pet_instance = bmi_PET.BMI_pet_model()
        # pet_instance.initialize(cfg_file='./Carmel_inputs_January_2017/pet_config/PET_Config_'+filename_without_extension+'.json', current_time_step=1)
       # # print(cfg_file)
        # pet_instance.update()
        # pet_instance.finalize()
        # pet = pet_instance.get_value('etr').values
        pet = 0

        # Construct forcing file name and read forcing file
        forcing_file_name = filename.replace('.json', '.csv')
        forcing_file_path = os.path.join(forcing_dir, forcing_file_name)
        # print(forcing_file_path)

        with open(forcing_file_path, 'r') as f:
            df_forcing = pd.read_csv(f)

        # Initialize output dictionary
        outputs = cfe_instance.get_output_var_names()
        output_lists = {output:[] for output in outputs}

        # Update CFE instance with each precipitation and PET values
        
        for t, precip in enumerate(df_forcing['APCP_surface']):
            precip = (precip)/1000
            # pet[t] = pet[t]/3600  #Unlock it if PET is being used
            cfe_instance.set_value('atmosphere_water__time_integral_of_precipitation_mass_flux', precip)    
    
            # cfe_instance.set_value('water_potential_evaporation_flux', pet[t])  #IF pet is used
            cfe_instance.set_value('water_potential_evaporation_flux', pet)
   
            cfe_instance.update()

            for output in outputs:
                output_lists[output].append(cfe_instance.get_value(output))

        cfe_instance.finalize(print_mass_balance=True)

        # Convert output dictionary to DataFrame
        df_output = pd.DataFrame(output_lists)

        # Write output to a CSV file in the output directory
        output_csv_file_path = os.path.join(output_dir, f'{os.path.splitext(filename)[0]}_output.csv')
        df_output.to_csv(output_csv_file_path, index=False)

        # Write output to a JSON file in the output directory
        # output_json_file_path = os.path.join(output_dir, f'{os.path.splitext(filename)[0]}_output.json')
        # with open(output_json_file_path, 'w') as json_file:
        #     json.dump(output_lists, json_file)
# Out:
# GLOBAL MASS BALANCE
#   initial volume:   1.1814
#     volume input:   0.0566
#    volume output:   0.5005
#     final volume:   0.7375
#         residual: -1.9984e-15
#
# PARTITION MASS BALANCE
#     surface runoff:   0.0157
#       infiltration:   0.0409
#  vol. et from rain:   0.0000
# partition residual: -7.6328e-17
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.0157
#    vol. out giuh:   0.0157
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.6966
#     vol. into soil:   0.0409
#   vol.soil2latflow:   0.0000
#    vol. soil to gw:   0.0000
#  vol. et from soil:   0.0000
#    final vol. soil:   0.7375
#   vol. soil resid.: -1.1102e-15
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   0.0000
#   vol. from nash:   0.0000
#  final vol. nash:   0.0000
# nash casc resid.: 0.0000e+00
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   0.4848
#        vol to gw:   0.0000
#      vol from gw:   0.4848
# final gw.storage:   0.0000
#     gw. residual: 8.5916e-16
#
# GLOBAL MASS BALANCE
#   initial volume:   1.2342
#     volume input:   0.0637
#    volume output:   0.5436
#     final volume:   0.7543
#         residual: 1.1102e-16
#
# PARTITION MASS BALANCE
#     surface runoff:   0.0021
#       infiltration:   0.0616
#  vol. et from rain:   0.0000
# partition residual: 5.5511e-17
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.0021
#    vol. out giuh:   0.0021
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.6927
#     vol. into soil:   0.0616
#   vol.soil2latflow:   0.0000
#    vol. soil to gw:   0.0000
#  vol. et from soil:   0.0000
#    final vol. soil:   0.7543
#   vol. soil resid.: 4.4409e-16
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   0.0000
#   vol. from nash:   0.0000
#  final vol. nash:   0.0000
# nash casc resid.: 0.0000e+00
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   0.5415
#        vol to gw:   0.0000
#      vol from gw:   0.5415
# final gw.storage:   0.0000
#     gw. residual: -2.8207e-16
#
# GLOBAL MASS BALANCE
#   initial volume:   1.2342
#     volume input:   0.0756
#    volume output:   0.5490
#     final volume:   0.7608
#         residual: -1.1102e-16
#
# PARTITION MASS BALANCE
#     surface runoff:   0.0075
#       infiltration:   0.0681
#  vol. et from rain:   0.0000
# partition residual: 6.9389e-17
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.0075
#    vol. out giuh:   0.0075
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.6927
#     vol. into soil:   0.0681
#   vol.soil2latflow:   0.0000
#    vol. soil to gw:   0.0000
#  vol. et from soil:   0.0000
#    final vol. soil:   0.7608
#   vol. soil resid.: 4.4409e-16
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   0.0000
#   vol. from nash:   0.0000
#  final vol. nash:   0.0000
# nash casc resid.: 0.0000e+00
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   0.5415
#        vol to gw:   0.0000
#      vol from gw:   0.5415
# final gw.storage:   0.0000
#     gw. residual: -2.8207e-16
#
# GLOBAL MASS BALANCE
#   initial volume:   1.4880
#     volume input:   0.0901
#    volume output:   0.9169
#     final volume:   0.6611
#         residual: 8.8818e-16
#
# PARTITION MASS BALANCE
#     surface runoff:   0.0215
#       infiltration:   0.0686
#  vol. et from rain:   0.0000
# partition residual: -8.3267e-17
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.0215
#    vol. out giuh:   0.0215
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.6900
#     vol. into soil:   0.0686
#   vol.soil2latflow:   0.0959
#    vol. soil to gw:   0.0015
#  vol. et from soil:   0.0000
#    final vol. soil:   0.6611
#   vol. soil resid.: 2.2204e-16
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   0.0959
#   vol. from nash:   0.0956
#  final vol. nash:   0.0003
# nash casc resid.: -1.8648e-17
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   0.7980
#        vol to gw:   0.0015
#      vol from gw:   0.7994
# final gw.storage:   0.0001
#     gw. residual: -6.2218e-16
#
# GLOBAL MASS BALANCE
#   initial volume:   1.2342
#     volume input:   0.0654
#    volume output:   0.5587
#     final volume:   0.7409
#         residual: -2.7756e-15
#
# PARTITION MASS BALANCE
#     surface runoff:   0.0172
#       infiltration:   0.0482
#  vol. et from rain:   0.0000
# partition residual: 5.5511e-17
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.0172
#    vol. out giuh:   0.0172
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.6927
#     vol. into soil:   0.0482
#   vol.soil2latflow:   0.0000
#    vol. soil to gw:   0.0000
#  vol. et from soil:   0.0000
#    final vol. soil:   0.7409
#   vol. soil resid.: -2.6645e-15
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   0.0000
#   vol. from nash:   0.0000
#  final vol. nash:   0.0000
# nash casc resid.: 0.0000e+00
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   0.5415
#        vol to gw:   0.0000
#      vol from gw:   0.5415
# final gw.storage:   0.0000
#     gw. residual: -2.8207e-16
#
# GLOBAL MASS BALANCE
#   initial volume:   2.2020
#     volume input:   0.0996
#    volume output:   1.9855
#     final volume:   0.3161
#         residual: 3.8858e-15
#
# PARTITION MASS BALANCE
#     surface runoff:   0.0127
#       infiltration:   0.0869
#  vol. et from rain:   0.0000
# partition residual: -1.9429e-16
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.0127
#    vol. out giuh:   0.0127
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.6094
#     vol. into soil:   0.0869
#   vol.soil2latflow:   0.3808
#    vol. soil to gw:   0.0139
#  vol. et from soil:   0.0000
#    final vol. soil:   0.3016
#   vol. soil resid.: 7.7716e-16
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   0.3808
#   vol. from nash:   0.3800
#  final vol. nash:   0.0007
# nash casc resid.: -4.1135e-16
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   1.5926
#        vol to gw:   0.0139
#      vol from gw:   1.5920
# final gw.storage:   0.0145
#     gw. residual: 1.9429e-16
#
# GLOBAL MASS BALANCE
#   initial volume:   1.5765
#     volume input:   0.0592
#    volume output:   0.9214
#     final volume:   0.7142
#         residual: 1.1102e-15
#
# PARTITION MASS BALANCE
#     surface runoff:   0.0112
#       infiltration:   0.0479
#  vol. et from rain:   0.0000
# partition residual: 5.5511e-17
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.0112
#    vol. out giuh:   0.0112
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.6661
#     vol. into soil:   0.0479
#   vol.soil2latflow:   0.0000
#    vol. soil to gw:   0.0000
#  vol. et from soil:   0.0000
#    final vol. soil:   0.7140
#   vol. soil resid.: 1.2212e-15
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   0.0000
#   vol. from nash:   0.0000
#  final vol. nash:   0.0000
# nash casc resid.: 0.0000e+00
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   0.9104
#        vol to gw:   0.0000
#      vol from gw:   0.9101
# final gw.storage:   0.0002
#     gw. residual: -3.4469e-16
#
# GLOBAL MASS BALANCE
#   initial volume:   1.2348
#     volume input:   0.0611
#    volume output:   0.5512
#     final volume:   0.7447
#         residual: 0.0000e+00
#
# PARTITION MASS BALANCE
#     surface runoff:   0.0096
#       infiltration:   0.0514
#  vol. et from rain:   0.0000
# partition residual: -6.2450e-17
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.0096
#    vol. out giuh:   0.0096
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.6933
#     vol. into soil:   0.0514
#   vol.soil2latflow:   0.0000
#    vol. soil to gw:   0.0000
#  vol. et from soil:   0.0000
#    final vol. soil:   0.7447
#   vol. soil resid.: 4.4409e-16
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   0.0000
#   vol. from nash:   0.0000
#  final vol. nash:   0.0000
# nash casc resid.: 0.0000e+00
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   0.5415
#        vol to gw:   0.0000
#      vol from gw:   0.5415
# final gw.storage:   0.0000
#     gw. residual: -2.8207e-16
#
# GLOBAL MASS BALANCE
#   initial volume:   1.5837
#     volume input:   0.0579
#    volume output:   0.9142
#     final volume:   0.7274
#         residual: -7.7716e-16
#
# PARTITION MASS BALANCE
#     surface runoff:   0.0040
#       infiltration:   0.0538
#  vol. et from rain:   0.0000
# partition residual: 1.3878e-17
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.0040
#    vol. out giuh:   0.0040
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.6733
#     vol. into soil:   0.0538
#   vol.soil2latflow:   0.0000
#    vol. soil to gw:   0.0000
#  vol. et from soil:   0.0000
#    final vol. soil:   0.7271
#   vol. soil resid.: -4.4409e-16
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   0.0000
#   vol. from nash:   0.0000
#  final vol. nash:   0.0000
# nash casc resid.: 0.0000e+00
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   0.9104
#        vol to gw:   0.0000
#      vol from gw:   0.9101
# final gw.storage:   0.0002
#     gw. residual: -3.4469e-16
#
# GLOBAL MASS BALANCE
#   initial volume:   1.2340
#     volume input:   0.0923
#    volume output:   0.5562
#     final volume:   0.7701
#         residual: -6.6613e-16
#
# PARTITION MASS BALANCE
#     surface runoff:   0.0147
#       infiltration:   0.0777
#  vol. et from rain:   0.0000
# partition residual: -2.2204e-16
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.0147
#    vol. out giuh:   0.0147
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.6924
#     vol. into soil:   0.0777
#   vol.soil2latflow:   0.0000
#    vol. soil to gw:   0.0000
#  vol. et from soil:   0.0000
#    final vol. soil:   0.7701
#   vol. soil resid.: 3.3307e-16
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   0.0000
#   vol. from nash:   0.0000
#  final vol. nash:   0.0000
# nash casc resid.: 0.0000e+00
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   0.5415
#        vol to gw:   0.0000
#      vol from gw:   0.5415
# final gw.storage:   0.0000
#     gw. residual: -2.8207e-16
#
# GLOBAL MASS BALANCE
#   initial volume:   1.1939
#     volume input:   0.0901
#    volume output:   0.7541
#     final volume:   0.5299
#         residual: 2.2204e-16
#
# PARTITION MASS BALANCE
#     surface runoff:   0.0356
#       infiltration:   0.0545
#  vol. et from rain:   0.0000
# partition residual: -1.3184e-16
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.0356
#    vol. out giuh:   0.0356
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.6524
#     vol. into soil:   0.0545
#   vol.soil2latflow:   0.1761
#    vol. soil to gw:   0.0009
#  vol. et from soil:   0.0000
#    final vol. soil:   0.5299
#   vol. soil resid.: 0.0000e+00
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   0.1761
#   vol. from nash:   0.1754
#  final vol. nash:   0.0006
# nash casc resid.: -4.0701e-16
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   0.5415
#        vol to gw:   0.0009
#      vol from gw:   0.5424
# final gw.storage:   0.0000
#     gw. residual: 3.6040e-16
#
# GLOBAL MASS BALANCE
#   initial volume:   1.4890
#     volume input:   0.1066
#    volume output:   0.8971
#     final volume:   0.6984
#         residual: 7.9835e-09
#
# PARTITION MASS BALANCE
#     surface runoff:   0.0348
#       infiltration:   0.0718
#  vol. et from rain:   0.0000
# partition residual: 2.7756e-17
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.0348
#    vol. out giuh:   0.0348
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.6910
#     vol. into soil:   0.0718
#   vol.soil2latflow:   0.0637
#    vol. soil to gw:   0.0008
#  vol. et from soil:   0.0000
#    final vol. soil:   0.6983
#   vol. soil resid.: 7.9835e-09
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   0.0637
#   vol. from nash:   0.0635
#  final vol. nash:   0.0002
# nash casc resid.: 7.6084e-17
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   0.7980
#        vol to gw:   0.0008
#      vol from gw:   0.7987
# final gw.storage:   0.0001
#     gw. residual: 2.7230e-16
#
# GLOBAL MASS BALANCE
#   initial volume:   1.1814
#     volume input:   0.0601
#    volume output:   0.4894
#     final volume:   0.7521
#         residual: 0.0000e+00
#
# PARTITION MASS BALANCE
#     surface runoff:   0.0046
#       infiltration:   0.0555
#  vol. et from rain:   0.0000
# partition residual: 7.6328e-17
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.0046
#    vol. out giuh:   0.0046
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.6966
#     vol. into soil:   0.0555
#   vol.soil2latflow:   0.0000
#    vol. soil to gw:   0.0000
#  vol. et from soil:   0.0000
#    final vol. soil:   0.7521
#   vol. soil resid.: -7.7716e-16
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   0.0000
#   vol. from nash:   0.0000
#  final vol. nash:   0.0000
# nash casc resid.: 0.0000e+00
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   0.4848
#        vol to gw:   0.0000
#      vol from gw:   0.4848
# final gw.storage:   0.0000
#     gw. residual: 8.5916e-16
#
# GLOBAL MASS BALANCE
#   initial volume:   1.1949
#     volume input:   0.0953
#    volume output:   0.7854
#     final volume:   0.5048
#         residual: -1.1102e-15
#
# PARTITION MASS BALANCE
#     surface runoff:   0.0022
#       infiltration:   0.0931
#  vol. et from rain:   0.0000
# partition residual: -1.3878e-17
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.0022
#    vol. out giuh:   0.0022
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.6534
#     vol. into soil:   0.0931
#   vol.soil2latflow:   0.2067
#    vol. soil to gw:   0.0353
#  vol. et from soil:   0.0000
#    final vol. soil:   0.5046
#   vol. soil resid.: 6.6613e-16
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   0.2067
#   vol. from nash:   0.2062
#  final vol. nash:   0.0004
# nash casc resid.: -6.8803e-16
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   0.5415
#        vol to gw:   0.0353
#      vol from gw:   0.5765
# final gw.storage:   0.0003
#     gw. residual: -6.9075e-16
#
# GLOBAL MASS BALANCE
#   initial volume:   1.1919
#     volume input:   0.0969
#    volume output:   0.6704
#     final volume:   0.6185
#         residual: 2.2204e-16
#
# PARTITION MASS BALANCE
#     surface runoff:   0.0110
#       infiltration:   0.0860
#  vol. et from rain:   0.0000
# partition residual: 5.5511e-17
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.0110
#    vol. out giuh:   0.0110
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.6504
#     vol. into soil:   0.0860
#   vol.soil2latflow:   0.1133
#    vol. soil to gw:   0.0046
#  vol. et from soil:   0.0000
#    final vol. soil:   0.6185
#   vol. soil resid.: -1.1102e-16
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   0.1133
#   vol. from nash:   0.1131
#  final vol. nash:   0.0002
# nash casc resid.: 1.1617e-16
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   0.5415
#        vol to gw:   0.0046
#      vol from gw:   0.5461
# final gw.storage:   0.0000
#     gw. residual: -3.0744e-16
#
# GLOBAL MASS BALANCE
#   initial volume:   1.2312
#     volume input:   0.0959
#    volume output:   0.6139
#     final volume:   0.7133
#         residual: 4.5659e-07
#
# PARTITION MASS BALANCE
#     surface runoff:   0.0143
#       infiltration:   0.0816
#  vol. et from rain:   0.0000
# partition residual: 6.9389e-17
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.0143
#    vol. out giuh:   0.0143
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.6897
#     vol. into soil:   0.0816
#   vol.soil2latflow:   0.0564
#    vol. soil to gw:   0.0017
#  vol. et from soil:   0.0000
#    final vol. soil:   0.7133
#   vol. soil resid.: 4.5659e-07
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   0.0564
#   vol. from nash:   0.0562
#  final vol. nash:   0.0003
# nash casc resid.: 4.2175e-17
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   0.5415
#        vol to gw:   0.0017
#      vol from gw:   0.5432
# final gw.storage:   0.0000
#     gw. residual: 5.3816e-16
#
# GLOBAL MASS BALANCE
#   initial volume:   1.2342
#     volume input:   0.0589
#    volume output:   0.5621
#     final volume:   0.7310
#         residual: -1.1102e-15
#
# PARTITION MASS BALANCE
#     surface runoff:   0.0206
#       infiltration:   0.0383
#  vol. et from rain:   0.0000
# partition residual: 8.3267e-17
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.0206
#    vol. out giuh:   0.0206
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.6927
#     vol. into soil:   0.0383
#   vol.soil2latflow:   0.0000
#    vol. soil to gw:   0.0000
#  vol. et from soil:   0.0000
#    final vol. soil:   0.7310
#   vol. soil resid.: -6.6613e-16
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   0.0000
#   vol. from nash:   0.0000
#  final vol. nash:   0.0000
# nash casc resid.: 0.0000e+00
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   0.5415
#        vol to gw:   0.0000
#      vol from gw:   0.5415
# final gw.storage:   0.0000
#     gw. residual: -2.8207e-16
#
# GLOBAL MASS BALANCE
#   initial volume:   1.4906
#     volume input:   0.1042
#    volume output:   0.9763
#     final volume:   0.6185
#         residual: 4.4409e-16
#
# PARTITION MASS BALANCE
#     surface runoff:   0.0188
#       infiltration:   0.0854
#  vol. et from rain:   0.0000
# partition residual: -5.5511e-17
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.0188
#    vol. out giuh:   0.0188
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.6926
#     vol. into soil:   0.0854
#   vol.soil2latflow:   0.1556
#    vol. soil to gw:   0.0041
#  vol. et from soil:   0.0000
#    final vol. soil:   0.6184
#   vol. soil resid.: 4.4409e-16
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   0.1556
#   vol. from nash:   0.1554
#  final vol. nash:   0.0002
# nash casc resid.: -7.4908e-16
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   0.7980
#        vol to gw:   0.0041
#      vol from gw:   0.8019
# final gw.storage:   0.0001
#     gw. residual: 3.4258e-16
#
# GLOBAL MASS BALANCE
#   initial volume:   1.1839
#     volume input:   0.1004
#    volume output:   0.7028
#     final volume:   0.5815
#         residual: -1.1102e-16
#
# PARTITION MASS BALANCE
#     surface runoff:   0.0167
#       infiltration:   0.0838
#  vol. et from rain:   0.0000
# partition residual: 1.3878e-17
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.0167
#    vol. out giuh:   0.0167
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.6424
#     vol. into soil:   0.0838
#   vol.soil2latflow:   0.1406
#    vol. soil to gw:   0.0041
#  vol. et from soil:   0.0000
#    final vol. soil:   0.5815
#   vol. soil resid.: -3.3307e-16
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   0.1406
#   vol. from nash:   0.1403
#  final vol. nash:   0.0003
# nash casc resid.: 8.4568e-16
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   0.5415
#        vol to gw:   0.0041
#      vol from gw:   0.5456
# final gw.storage:   0.0000
#     gw. residual: 4.5902e-17
#
# GLOBAL MASS BALANCE
#   initial volume:   1.5798
#     volume input:   0.0568
#    volume output:   0.9136
#     final volume:   0.7230
#         residual: -2.3315e-15
#
# PARTITION MASS BALANCE
#     surface runoff:   0.0034
#       infiltration:   0.0533
#  vol. et from rain:   0.0000
# partition residual: 8.3267e-17
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.0034
#    vol. out giuh:   0.0034
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.6695
#     vol. into soil:   0.0533
#   vol.soil2latflow:   0.0000
#    vol. soil to gw:   0.0000
#  vol. et from soil:   0.0000
#    final vol. soil:   0.7228
#   vol. soil resid.: -2.3315e-15
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   0.0000
#   vol. from nash:   0.0000
#  final vol. nash:   0.0000
# nash casc resid.: 0.0000e+00
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   0.9104
#        vol to gw:   0.0000
#      vol from gw:   0.9101
# final gw.storage:   0.0002
#     gw. residual: -3.4469e-16
#
# GLOBAL MASS BALANCE
#   initial volume:   1.2342
#     volume input:   0.0691
#    volume output:   0.5455
#     final volume:   0.7578
#         residual: 1.9292e-07
#
# PARTITION MASS BALANCE
#     surface runoff:   0.0009
#       infiltration:   0.0683
#  vol. et from rain:   0.0000
# partition residual: 4.1633e-17
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.0009
#    vol. out giuh:   0.0009
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.6927
#     vol. into soil:   0.0683
#   vol.soil2latflow:   0.0022
#    vol. soil to gw:   0.0012
#  vol. et from soil:   0.0000
#    final vol. soil:   0.7575
#   vol. soil resid.: 1.9292e-07
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   0.0022
#   vol. from nash:   0.0018
#  final vol. nash:   0.0004
# nash casc resid.: 1.8431e-18
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   0.5415
#        vol to gw:   0.0012
#      vol from gw:   0.5425
# final gw.storage:   0.0003
#     gw. residual: -1.5266e-16
#
# GLOBAL MASS BALANCE
#   initial volume:   1.1839
#     volume input:   0.1073
#    volume output:   0.6941
#     final volume:   0.5971
#         residual: 2.6645e-15
#
# PARTITION MASS BALANCE
#     surface runoff:   0.0303
#       infiltration:   0.0770
#  vol. et from rain:   0.0000
# partition residual: -6.9389e-17
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.0303
#    vol. out giuh:   0.0303
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.6424
#     vol. into soil:   0.0770
#   vol.soil2latflow:   0.1184
#    vol. soil to gw:   0.0039
#  vol. et from soil:   0.0000
#    final vol. soil:   0.5970
#   vol. soil resid.: 3.3307e-16
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   0.1184
#   vol. from nash:   0.1183
#  final vol. nash:   0.0001
# nash casc resid.: -2.5858e-16
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   0.5415
#        vol to gw:   0.0039
#      vol from gw:   0.5454
# final gw.storage:   0.0000
#     gw. residual: 1.6479e-15
#
# GLOBAL MASS BALANCE
#   initial volume:   1.1883
#     volume input:   0.0976
#    volume output:   0.6950
#     final volume:   0.5908
#         residual: 7.7716e-16
#
# PARTITION MASS BALANCE
#     surface runoff:   0.0181
#       infiltration:   0.0795
#  vol. et from rain:   0.0000
# partition residual: 0.0000e+00
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.0181
#    vol. out giuh:   0.0181
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.6467
#     vol. into soil:   0.0795
#   vol.soil2latflow:   0.1325
#    vol. soil to gw:   0.0030
#  vol. et from soil:   0.0000
#    final vol. soil:   0.5907
#   vol. soil resid.: 0.0000e+00
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   0.1325
#   vol. from nash:   0.1318
#  final vol. nash:   0.0007
# nash casc resid.: 1.9190e-16
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   0.5415
#        vol to gw:   0.0030
#      vol from gw:   0.5445
# final gw.storage:   0.0000
#     gw. residual: 8.9233e-16
#
# GLOBAL MASS BALANCE
#   initial volume:   1.1839
#     volume input:   0.1013
#    volume output:   0.7347
#     final volume:   0.5506
#         residual: -7.7716e-16
#
# PARTITION MASS BALANCE
#     surface runoff:   0.0102
#       infiltration:   0.0911
#  vol. et from rain:   0.0000
# partition residual: -1.1102e-16
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.0102
#    vol. out giuh:   0.0102
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.6424
#     vol. into soil:   0.0911
#   vol.soil2latflow:   0.1766
#    vol. soil to gw:   0.0064
#  vol. et from soil:   0.0000
#    final vol. soil:   0.5505
#   vol. soil resid.: 1.1102e-16
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   0.1766
#   vol. from nash:   0.1763
#  final vol. nash:   0.0003
# nash casc resid.: -5.1608e-17
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   0.5415
#        vol to gw:   0.0064
#      vol from gw:   0.5478
# final gw.storage:   0.0000
#     gw. residual: 3.7954e-16
#
# GLOBAL MASS BALANCE
#   initial volume:   1.2342
#     volume input:   0.0580
#    volume output:   0.5548
#     final volume:   0.7374
#         residual: -9.9920e-16
#
# PARTITION MASS BALANCE
#     surface runoff:   0.0133
#       infiltration:   0.0447
#  vol. et from rain:   0.0000
# partition residual: -8.3267e-17
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.0133
#    vol. out giuh:   0.0133
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.6927
#     vol. into soil:   0.0447
#   vol.soil2latflow:   0.0000
#    vol. soil to gw:   0.0000
#  vol. et from soil:   0.0000
#    final vol. soil:   0.7374
#   vol. soil resid.: -1.1102e-16
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   0.0000
#   vol. from nash:   0.0000
#  final vol. nash:   0.0000
# nash casc resid.: 0.0000e+00
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   0.5415
#        vol to gw:   0.0000
#      vol from gw:   0.5415
# final gw.storage:   0.0000
#     gw. residual: -2.8207e-16
#
# GLOBAL MASS BALANCE
#   initial volume:   1.2342
#     volume input:   0.0620
#    volume output:   0.5543
#     final volume:   0.7419
#         residual: 6.6613e-16
#
# PARTITION MASS BALANCE
#     surface runoff:   0.0127
#       infiltration:   0.0492
#  vol. et from rain:   0.0000
# partition residual: 8.3267e-17
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.0127
#    vol. out giuh:   0.0127
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.6927
#     vol. into soil:   0.0492
#   vol.soil2latflow:   0.0000
#    vol. soil to gw:   0.0000
#  vol. et from soil:   0.0000
#    final vol. soil:   0.7419
#   vol. soil resid.: 6.6613e-16
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   0.0000
#   vol. from nash:   0.0000
#  final vol. nash:   0.0000
# nash casc resid.: 0.0000e+00
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   0.5415
#        vol to gw:   0.0000
#      vol from gw:   0.5415
# final gw.storage:   0.0000
#     gw. residual: -2.8207e-16
#
# GLOBAL MASS BALANCE
#   initial volume:   1.2198
#     volume input:   0.0957
#    volume output:   0.5817
#     final volume:   0.7339
#         residual: 1.6509e-08
#
# PARTITION MASS BALANCE
#     surface runoff:   0.0124
#       infiltration:   0.0833
#  vol. et from rain:   0.0000
# partition residual: 4.1633e-17
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.0124
#    vol. out giuh:   0.0124
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.6783
#     vol. into soil:   0.0833
#   vol.soil2latflow:   0.0267
#    vol. soil to gw:   0.0010
#  vol. et from soil:   0.0000
#    final vol. soil:   0.7338
#   vol. soil resid.: 1.6509e-08
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   0.0267
#   vol. from nash:   0.0265
#  final vol. nash:   0.0002
# nash casc resid.: 3.5237e-19
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   0.5415
#        vol to gw:   0.0010
#      vol from gw:   0.5425
# final gw.storage:   0.0000
#     gw. residual: -7.5722e-16
#
# GLOBAL MASS BALANCE
#   initial volume:   1.2342
#     volume input:   0.0660
#    volume output:   0.5486
#     final volume:   0.7516
#         residual: -9.9920e-16
#
# PARTITION MASS BALANCE
#     surface runoff:   0.0071
#       infiltration:   0.0589
#  vol. et from rain:   0.0000
# partition residual: -9.7145e-17
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.0071
#    vol. out giuh:   0.0071
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.6927
#     vol. into soil:   0.0589
#   vol.soil2latflow:   0.0000
#    vol. soil to gw:   0.0000
#  vol. et from soil:   0.0000
#    final vol. soil:   0.7516
#   vol. soil resid.: -5.5511e-16
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   0.0000
#   vol. from nash:   0.0000
#  final vol. nash:   0.0000
# nash casc resid.: 0.0000e+00
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   0.5415
#        vol to gw:   0.0000
#      vol from gw:   0.5415
# final gw.storage:   0.0000
#     gw. residual: -2.8207e-16
#
# GLOBAL MASS BALANCE
#   initial volume:   1.2342
#     volume input:   0.0637
#    volume output:   0.5678
#     final volume:   0.7301
#         residual: 5.5511e-16
#
# PARTITION MASS BALANCE
#     surface runoff:   0.0263
#       infiltration:   0.0374
#  vol. et from rain:   0.0000
# partition residual: -6.9389e-18
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.0263
#    vol. out giuh:   0.0263
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.6927
#     vol. into soil:   0.0374
#   vol.soil2latflow:   0.0000
#    vol. soil to gw:   0.0000
#  vol. et from soil:   0.0000
#    final vol. soil:   0.7301
#   vol. soil resid.: 5.5511e-16
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   0.0000
#   vol. from nash:   0.0000
#  final vol. nash:   0.0000
# nash casc resid.: 0.0000e+00
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   0.5415
#        vol to gw:   0.0000
#      vol from gw:   0.5415
# final gw.storage:   0.0000
#     gw. residual: -2.8207e-16
#
# GLOBAL MASS BALANCE
#   initial volume:   1.1865
#     volume input:   0.0976
#    volume output:   0.7625
#     final volume:   0.5216
#         residual: 7.7716e-16
#
# PARTITION MASS BALANCE
#     surface runoff:   0.0075
#       infiltration:   0.0901
#  vol. et from rain:   0.0000
# partition residual: -2.7756e-17
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.0075
#    vol. out giuh:   0.0075
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.6450
#     vol. into soil:   0.0901
#   vol.soil2latflow:   0.1818
#    vol. soil to gw:   0.0318
#  vol. et from soil:   0.0000
#    final vol. soil:   0.5215
#   vol. soil resid.: -2.2204e-16
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   0.1818
#   vol. from nash:   0.1816
#  final vol. nash:   0.0002
# nash casc resid.: 5.0871e-16
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   0.5415
#        vol to gw:   0.0318
#      vol from gw:   0.5732
# final gw.storage:   0.0001
#     gw. residual: -1.1556e-15
#
# GLOBAL MASS BALANCE
#   initial volume:   1.2322
#     volume input:   0.0602
#    volume output:   0.5483
#     final volume:   0.7440
#         residual: 6.6613e-16
#
# PARTITION MASS BALANCE
#     surface runoff:   0.0068
#       infiltration:   0.0534
#  vol. et from rain:   0.0000
# partition residual: -7.6328e-17
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.0068
#    vol. out giuh:   0.0068
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.6906
#     vol. into soil:   0.0534
#   vol.soil2latflow:   0.0000
#    vol. soil to gw:   0.0000
#  vol. et from soil:   0.0000
#    final vol. soil:   0.7440
#   vol. soil resid.: 1.1102e-15
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   0.0000
#   vol. from nash:   0.0000
#  final vol. nash:   0.0000
# nash casc resid.: 0.0000e+00
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   0.5415
#        vol to gw:   0.0000
#      vol from gw:   0.5415
# final gw.storage:   0.0000
#     gw. residual: -2.8207e-16
#
# GLOBAL MASS BALANCE
#   initial volume:   1.2342
#     volume input:   0.0604
#    volume output:   0.5525
#     final volume:   0.7422
#         residual: -2.2204e-16
#
# PARTITION MASS BALANCE
#     surface runoff:   0.0109
#       infiltration:   0.0495
#  vol. et from rain:   0.0000
# partition residual: 7.6328e-17
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.0109
#    vol. out giuh:   0.0109
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.6927
#     vol. into soil:   0.0495
#   vol.soil2latflow:   0.0000
#    vol. soil to gw:   0.0000
#  vol. et from soil:   0.0000
#    final vol. soil:   0.7421
#   vol. soil resid.: -2.2204e-16
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   0.0000
#   vol. from nash:   0.0000
#  final vol. nash:   0.0000
# nash casc resid.: 0.0000e+00
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   0.5415
#        vol to gw:   0.0000
#      vol from gw:   0.5415
# final gw.storage:   0.0000
#     gw. residual: -2.8207e-16
#
# GLOBAL MASS BALANCE
#   initial volume:   1.2416
#     volume input:   0.0665
#    volume output:   0.5613
#     final volume:   0.7468
#         residual: 1.2212e-15
#
# PARTITION MASS BALANCE
#     surface runoff:   0.0197
#       infiltration:   0.0468
#  vol. et from rain:   0.0000
# partition residual: -1.1102e-16
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.0197
#    vol. out giuh:   0.0197
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.7000
#     vol. into soil:   0.0468
#   vol.soil2latflow:   0.0000
#    vol. soil to gw:   0.0000
#  vol. et from soil:   0.0000
#    final vol. soil:   0.7468
#   vol. soil resid.: 1.5543e-15
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   0.0000
#   vol. from nash:   0.0000
#  final vol. nash:   0.0000
# nash casc resid.: 0.0000e+00
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   0.5415
#        vol to gw:   0.0000
#      vol from gw:   0.5415
# final gw.storage:   0.0000
#     gw. residual: -2.8207e-16
#
# GLOBAL MASS BALANCE
#   initial volume:   1.2198
#     volume input:   0.0787
#    volume output:   0.5578
#     final volume:   0.7407
#         residual: 5.5511e-16
#
# PARTITION MASS BALANCE
#     surface runoff:   0.0163
#       infiltration:   0.0624
#  vol. et from rain:   0.0000
# partition residual: -6.9389e-17
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.0163
#    vol. out giuh:   0.0163
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.6783
#     vol. into soil:   0.0624
#   vol.soil2latflow:   0.0000
#    vol. soil to gw:   0.0000
#  vol. et from soil:   0.0000
#    final vol. soil:   0.7407
#   vol. soil resid.: 6.6613e-16
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   0.0000
#   vol. from nash:   0.0000
#  final vol. nash:   0.0000
# nash casc resid.: 0.0000e+00
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   0.5415
#        vol to gw:   0.0000
#      vol from gw:   0.5415
# final gw.storage:   0.0000
#     gw. residual: -2.8207e-16
#
# GLOBAL MASS BALANCE
#   initial volume:   1.2342
#     volume input:   0.0560
#    volume output:   0.5495
#     final volume:   0.7407
#         residual: -2.2204e-16
#
# PARTITION MASS BALANCE
#     surface runoff:   0.0080
#       infiltration:   0.0480
#  vol. et from rain:   0.0000
# partition residual: -2.0817e-17
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.0080
#    vol. out giuh:   0.0080
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.6927
#     vol. into soil:   0.0480
#   vol.soil2latflow:   0.0000
#    vol. soil to gw:   0.0000
#  vol. et from soil:   0.0000
#    final vol. soil:   0.7407
#   vol. soil resid.: 0.0000e+00
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   0.0000
#   vol. from nash:   0.0000
#  final vol. nash:   0.0000
# nash casc resid.: 0.0000e+00
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   0.5415
#        vol to gw:   0.0000
#      vol from gw:   0.5415
# final gw.storage:   0.0000
#     gw. residual: -2.8207e-16
#
# GLOBAL MASS BALANCE
#   initial volume:   1.2334
#     volume input:   0.0594
#    volume output:   0.5494
#     final volume:   0.7433
#         residual: -1.3323e-15
#
# PARTITION MASS BALANCE
#     surface runoff:   0.0079
#       infiltration:   0.0514
#  vol. et from rain:   0.0000
# partition residual: 7.6328e-17
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.0079
#    vol. out giuh:   0.0079
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.6918
#     vol. into soil:   0.0514
#   vol.soil2latflow:   0.0000
#    vol. soil to gw:   0.0000
#  vol. et from soil:   0.0000
#    final vol. soil:   0.7433
#   vol. soil resid.: -1.1102e-15
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   0.0000
#   vol. from nash:   0.0000
#  final vol. nash:   0.0000
# nash casc resid.: 0.0000e+00
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   0.5415
#        vol to gw:   0.0000
#      vol from gw:   0.5415
# final gw.storage:   0.0000
#     gw. residual: -2.8207e-16
#
# GLOBAL MASS BALANCE
#   initial volume:   1.1932
#     volume input:   0.0904
#    volume output:   0.8091
#     final volume:   0.4745
#         residual: -5.5511e-17
#
# PARTITION MASS BALANCE
#     surface runoff:   0.0068
#       infiltration:   0.0836
#  vol. et from rain:   0.0000
# partition residual: 5.5511e-17
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.0068
#    vol. out giuh:   0.0068
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.6516
#     vol. into soil:   0.0836
#   vol.soil2latflow:   0.2519
#    vol. soil to gw:   0.0089
#  vol. et from soil:   0.0000
#    final vol. soil:   0.4744
#   vol. soil resid.: 2.7756e-16
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   0.2519
#   vol. from nash:   0.2514
#  final vol. nash:   0.0006
# nash casc resid.: -1.6859e-16
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   0.5415
#        vol to gw:   0.0089
#      vol from gw:   0.5503
# final gw.storage:   0.0001
#     gw. residual: -1.4469e-15
#
# GLOBAL MASS BALANCE
#   initial volume:   1.2342
#     volume input:   0.0577
#    volume output:   0.5462
#     final volume:   0.7458
#         residual: -1.4433e-15
#
# PARTITION MASS BALANCE
#     surface runoff:   0.0046
#       infiltration:   0.0531
#  vol. et from rain:   0.0000
# partition residual: 3.4694e-17
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.0046
#    vol. out giuh:   0.0046
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.6927
#     vol. into soil:   0.0531
#   vol.soil2latflow:   0.0000
#    vol. soil to gw:   0.0000
#  vol. et from soil:   0.0000
#    final vol. soil:   0.7458
#   vol. soil resid.: -1.2212e-15
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   0.0000
#   vol. from nash:   0.0000
#  final vol. nash:   0.0000
# nash casc resid.: 0.0000e+00
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   0.5415
#        vol to gw:   0.0000
#      vol from gw:   0.5415
# final gw.storage:   0.0000
#     gw. residual: -2.8207e-16
#
# GLOBAL MASS BALANCE
#   initial volume:   1.2336
#     volume input:   0.0857
#    volume output:   0.5539
#     final volume:   0.7655
#         residual: -2.7756e-15
#
# PARTITION MASS BALANCE
#     surface runoff:   0.0124
#       infiltration:   0.0734
#  vol. et from rain:   0.0000
# partition residual: 1.5266e-16
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.0124
#    vol. out giuh:   0.0124
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.6921
#     vol. into soil:   0.0734
#   vol.soil2latflow:   0.0000
#    vol. soil to gw:   0.0000
#  vol. et from soil:   0.0000
#    final vol. soil:   0.7655
#   vol. soil resid.: -1.9984e-15
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   0.0000
#   vol. from nash:   0.0000
#  final vol. nash:   0.0000
# nash casc resid.: 0.0000e+00
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   0.5415
#        vol to gw:   0.0000
#      vol from gw:   0.5415
# final gw.storage:   0.0000
#     gw. residual: -2.8207e-16
#
# GLOBAL MASS BALANCE
#   initial volume:   1.2310
#     volume input:   0.0583
#    volume output:   0.5531
#     final volume:   0.7362
#         residual: 1.5771e-08
#
# PARTITION MASS BALANCE
#     surface runoff:   0.0082
#       infiltration:   0.0501
#  vol. et from rain:   0.0000
# partition residual: -6.9389e-17
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.0082
#    vol. out giuh:   0.0082
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.6895
#     vol. into soil:   0.0501
#   vol.soil2latflow:   0.0033
#    vol. soil to gw:   0.0001
#  vol. et from soil:   0.0000
#    final vol. soil:   0.7362
#   vol. soil resid.: 1.5771e-08
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   0.0033
#   vol. from nash:   0.0031
#  final vol. nash:   0.0002
# nash casc resid.: 3.0358e-18
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   0.5415
#        vol to gw:   0.0001
#      vol from gw:   0.5416
# final gw.storage:   0.0000
#     gw. residual: -1.0326e-15
#
# GLOBAL MASS BALANCE
#   initial volume:   1.2342
#     volume input:   0.0889
#    volume output:   0.5573
#     final volume:   0.7657
#         residual: -3.1086e-15
#
# PARTITION MASS BALANCE
#     surface runoff:   0.0158
#       infiltration:   0.0731
#  vol. et from rain:   0.0000
# partition residual: 4.1633e-17
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.0158
#    vol. out giuh:   0.0158
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.6927
#     vol. into soil:   0.0731
#   vol.soil2latflow:   0.0000
#    vol. soil to gw:   0.0000
#  vol. et from soil:   0.0000
#    final vol. soil:   0.7657
#   vol. soil resid.: -2.8866e-15
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   0.0000
#   vol. from nash:   0.0000
#  final vol. nash:   0.0000
# nash casc resid.: 0.0000e+00
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   0.5415
#        vol to gw:   0.0000
#      vol from gw:   0.5415
# final gw.storage:   0.0000
#     gw. residual: -2.8207e-16
#
# GLOBAL MASS BALANCE
#   initial volume:   0.7483
#     volume input:   0.0981
#    volume output:   0.5424
#     final volume:   0.3040
#         residual: -6.1062e-16
#
# PARTITION MASS BALANCE
#     surface runoff:   0.0086
#       infiltration:   0.0895
#  vol. et from rain:   0.0000
# partition residual: -2.0817e-16
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.0086
#    vol. out giuh:   0.0086
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.6173
#     vol. into soil:   0.0895
#   vol.soil2latflow:   0.3931
#    vol. soil to gw:   0.0097
#  vol. et from soil:   0.0000
#    final vol. soil:   0.3040
#   vol. soil resid.: -5.5511e-17
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   0.3931
#   vol. from nash:   0.3924
#  final vol. nash:   0.0007
# nash casc resid.: 5.9360e-16
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   0.1310
#        vol to gw:   0.0097
#      vol from gw:   0.1407
# final gw.storage:   0.0000
#     gw. residual: -1.0594e-16
#
# GLOBAL MASS BALANCE
#   initial volume:   1.2149
#     volume input:   0.0969
#    volume output:   0.5766
#     final volume:   0.7353
#         residual: -4.4409e-16
#
# PARTITION MASS BALANCE
#     surface runoff:   0.0350
#       infiltration:   0.0618
#  vol. et from rain:   0.0000
# partition residual: 3.4694e-17
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.0350
#    vol. out giuh:   0.0350
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.6734
#     vol. into soil:   0.0618
#   vol.soil2latflow:   0.0000
#    vol. soil to gw:   0.0000
#  vol. et from soil:   0.0000
#    final vol. soil:   0.7353
#   vol. soil resid.: -1.1102e-16
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   0.0000
#   vol. from nash:   0.0000
#  final vol. nash:   0.0000
# nash casc resid.: 0.0000e+00
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   0.5415
#        vol to gw:   0.0000
#      vol from gw:   0.5415
# final gw.storage:   0.0000
#     gw. residual: -2.8207e-16
#
# GLOBAL MASS BALANCE
#   initial volume:   2.2091
#     volume input:   0.0991
#    volume output:   2.0097
#     final volume:   0.2984
#         residual: 6.4393e-15
#
# PARTITION MASS BALANCE
#     surface runoff:   0.0151
#       infiltration:   0.0840
#  vol. et from rain:   0.0000
# partition residual: 8.3267e-17
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.0151
#    vol. out giuh:   0.0151
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.6165
#     vol. into soil:   0.0840
#   vol.soil2latflow:   0.4063
#    vol. soil to gw:   0.0100
#  vol. et from soil:   0.0000
#    final vol. soil:   0.2841
#   vol. soil resid.: 4.9960e-16
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   0.4063
#   vol. from nash:   0.4055
#  final vol. nash:   0.0009
# nash casc resid.: 1.9798e-16
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   1.5926
#        vol to gw:   0.0100
#      vol from gw:   1.5883
# final gw.storage:   0.0143
#     gw. residual: 2.1823e-15
#
# GLOBAL MASS BALANCE
#   initial volume:   1.1937
#     volume input:   0.0888
#    volume output:   0.6458
#     final volume:   0.6368
#         residual: -3.2196e-15
#
# PARTITION MASS BALANCE
#     surface runoff:   0.0232
#       infiltration:   0.0656
#  vol. et from rain:   0.0000
# partition residual: 2.4980e-16
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.0232
#    vol. out giuh:   0.0232
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.6522
#     vol. into soil:   0.0656
#   vol.soil2latflow:   0.0804
#    vol. soil to gw:   0.0007
#  vol. et from soil:   0.0000
#    final vol. soil:   0.6368
#   vol. soil resid.: -1.1102e-16
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   0.0804
#   vol. from nash:   0.0800
#  final vol. nash:   0.0004
# nash casc resid.: 1.2967e-16
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   0.5415
#        vol to gw:   0.0007
#      vol from gw:   0.5422
# final gw.storage:   0.0000
#     gw. residual: -7.5811e-16
#
# GLOBAL MASS BALANCE
#   initial volume:   1.1848
#     volume input:   0.1036
#    volume output:   0.7495
#     final volume:   0.5390
#         residual: 9.9920e-16
#
# PARTITION MASS BALANCE
#     surface runoff:   0.0127
#       infiltration:   0.0909
#  vol. et from rain:   0.0000
# partition residual: -2.7756e-17
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.0127
#    vol. out giuh:   0.0127
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.6433
#     vol. into soil:   0.0909
#   vol.soil2latflow:   0.1896
#    vol. soil to gw:   0.0056
#  vol. et from soil:   0.0000
#    final vol. soil:   0.5389
#   vol. soil resid.: 3.3307e-16
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   0.1896
#   vol. from nash:   0.1894
#  final vol. nash:   0.0003
# nash casc resid.: -3.9893e-16
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   0.5415
#        vol to gw:   0.0056
#      vol from gw:   0.5471
# final gw.storage:   0.0000
#     gw. residual: 9.1221e-16
#
# GLOBAL MASS BALANCE
#   initial volume:   1.2331
#     volume input:   0.0646
#    volume output:   0.5468
#     final volume:   0.7508
#         residual: 0.0000e+00
#
# PARTITION MASS BALANCE
#     surface runoff:   0.0053
#       infiltration:   0.0592
#  vol. et from rain:   0.0000
# partition residual: 6.9389e-17
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.0053
#    vol. out giuh:   0.0053
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.6916
#     vol. into soil:   0.0592
#   vol.soil2latflow:   0.0000
#    vol. soil to gw:   0.0000
#  vol. et from soil:   0.0000
#    final vol. soil:   0.7508
#   vol. soil resid.: 3.3307e-16
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   0.0000
#   vol. from nash:   0.0000
#  final vol. nash:   0.0000
# nash casc resid.: 0.0000e+00
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   0.5415
#        vol to gw:   0.0000
#      vol from gw:   0.5415
# final gw.storage:   0.0000
#     gw. residual: -2.8207e-16
#
# GLOBAL MASS BALANCE
#   initial volume:   0.7911
#     volume input:   0.0936
#    volume output:   0.3146
#     final volume:   0.5701
#         residual: -7.7716e-16
#
# PARTITION MASS BALANCE
#     surface runoff:   0.0028
#       infiltration:   0.0908
#  vol. et from rain:   0.0000
# partition residual: 9.7145e-17
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.0028
#    vol. out giuh:   0.0028
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.6601
#     vol. into soil:   0.0908
#   vol.soil2latflow:   0.1686
#    vol. soil to gw:   0.0122
#  vol. et from soil:   0.0000
#    final vol. soil:   0.5701
#   vol. soil resid.: -3.3307e-16
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   0.1686
#   vol. from nash:   0.1682
#  final vol. nash:   0.0005
# nash casc resid.: 3.7058e-16
#
# ...
#     volume input:   0.0576
#    volume output:   0.5553
#     final volume:   0.7365
#         residual: -3.3307e-16
#
# PARTITION MASS BALANCE
#     surface runoff:   0.0138
#       infiltration:   0.0438
#  vol. et from rain:   0.0000
# partition residual: -1.5266e-16
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.0138
#    vol. out giuh:   0.0138
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.6927
#     vol. into soil:   0.0438
#   vol.soil2latflow:   0.0000
#    vol. soil to gw:   0.0000
#  vol. et from soil:   0.0000
#    final vol. soil:   0.7365
#   vol. soil resid.: 1.1102e-16
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   0.0000
#   vol. from nash:   0.0000
#  final vol. nash:   0.0000
# nash casc resid.: 0.0000e+00
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   0.5415
#        vol to gw:   0.0000
#      vol from gw:   0.5415
# final gw.storage:   0.0000
#     gw. residual: -2.8207e-16
#
# GLOBAL MASS BALANCE
#   initial volume:   1.1814
#     volume input:   0.0679
#    volume output:   0.5019
#     final volume:   0.7474
#         residual: 9.9920e-16
#
# PARTITION MASS BALANCE
#     surface runoff:   0.0171
#       infiltration:   0.0508
#  vol. et from rain:   0.0000
# partition residual: 3.4694e-17
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.0171
#    vol. out giuh:   0.0171
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.6966
#     vol. into soil:   0.0508
#   vol.soil2latflow:   0.0000
#    vol. soil to gw:   0.0000
#  vol. et from soil:   0.0000
#    final vol. soil:   0.7474
#   vol. soil resid.: 1.2212e-15
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   0.0000
#   vol. from nash:   0.0000
#  final vol. nash:   0.0000
# nash casc resid.: 0.0000e+00
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   0.4848
#        vol to gw:   0.0000
#      vol from gw:   0.4848
# final gw.storage:   0.0000
#     gw. residual: 8.5916e-16
#
# GLOBAL MASS BALANCE
#   initial volume:   1.2342
#     volume input:   0.0699
#    volume output:   0.5646
#     final volume:   0.7395
#         residual: -1.1102e-15
#
# PARTITION MASS BALANCE
#     surface runoff:   0.0231
#       infiltration:   0.0468
#  vol. et from rain:   0.0000
# partition residual: 4.1633e-17
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.0231
#    vol. out giuh:   0.0231
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.6927
#     vol. into soil:   0.0468
#   vol.soil2latflow:   0.0000
#    vol. soil to gw:   0.0000
#  vol. et from soil:   0.0000
#    final vol. soil:   0.7395
#   vol. soil resid.: -8.8818e-16
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   0.0000
#   vol. from nash:   0.0000
#  final vol. nash:   0.0000
# nash casc resid.: 0.0000e+00
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   0.5415
#        vol to gw:   0.0000
#      vol from gw:   0.5415
# final gw.storage:   0.0000
#     gw. residual: -2.8207e-16
#
# GLOBAL MASS BALANCE
#   initial volume:   1.2344
#     volume input:   0.0628
#    volume output:   0.5540
#     final volume:   0.7432
#         residual: -1.1102e-16
#
# PARTITION MASS BALANCE
#     surface runoff:   0.0125
#       infiltration:   0.0503
#  vol. et from rain:   0.0000
# partition residual: 2.0817e-17
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.0125
#    vol. out giuh:   0.0125
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.6929
#     vol. into soil:   0.0503
#   vol.soil2latflow:   0.0000
#    vol. soil to gw:   0.0000
#  vol. et from soil:   0.0000
#    final vol. soil:   0.7432
#   vol. soil resid.: 5.5511e-16
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   0.0000
#   vol. from nash:   0.0000
#  final vol. nash:   0.0000
# nash casc resid.: 0.0000e+00
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   0.5415
#        vol to gw:   0.0000
#      vol from gw:   0.5415
# final gw.storage:   0.0000
#     gw. residual: -2.8207e-16
#
# GLOBAL MASS BALANCE
#   initial volume:   1.2350
#     volume input:   0.0632
#    volume output:   0.5508
#     final volume:   0.7474
#         residual: -2.8866e-15
#
# PARTITION MASS BALANCE
#     surface runoff:   0.0093
#       infiltration:   0.0540
#  vol. et from rain:   0.0000
# partition residual: 5.5511e-17
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.0093
#    vol. out giuh:   0.0093
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.6934
#     vol. into soil:   0.0540
#   vol.soil2latflow:   0.0000
#    vol. soil to gw:   0.0000
#  vol. et from soil:   0.0000
#    final vol. soil:   0.7474
#   vol. soil resid.: -3.2196e-15
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   0.0000
#   vol. from nash:   0.0000
#  final vol. nash:   0.0000
# nash casc resid.: 0.0000e+00
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   0.5415
#        vol to gw:   0.0000
#      vol from gw:   0.5415
# final gw.storage:   0.0000
#     gw. residual: -2.8207e-16
#
# GLOBAL MASS BALANCE
#   initial volume:   1.4923
#     volume input:   0.0865
#    volume output:   1.0390
#     final volume:   0.5398
#         residual: 6.3283e-15
#
# PARTITION MASS BALANCE
#     surface runoff:   0.0047
#       infiltration:   0.0818
#  vol. et from rain:   0.0000
# partition residual: -1.3878e-17
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.0047
#    vol. out giuh:   0.0047
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.6943
#     vol. into soil:   0.0818
#   vol.soil2latflow:   0.2176
#    vol. soil to gw:   0.0189
#  vol. et from soil:   0.0000
#    final vol. soil:   0.5396
#   vol. soil resid.: 0.0000e+00
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   0.2176
#   vol. from nash:   0.2172
#  final vol. nash:   0.0004
# nash casc resid.: 2.4189e-16
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   0.7980
#        vol to gw:   0.0189
#      vol from gw:   0.8167
# final gw.storage:   0.0002
#     gw. residual: -8.4134e-17
#
# GLOBAL MASS BALANCE
#   initial volume:   1.2342
#     volume input:   0.0804
#    volume output:   0.5619
#     final volume:   0.7526
#         residual: 9.9920e-16
#
# PARTITION MASS BALANCE
#     surface runoff:   0.0204
#       infiltration:   0.0600
#  vol. et from rain:   0.0000
# partition residual: -1.3878e-16
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.0204
#    vol. out giuh:   0.0204
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.6927
#     vol. into soil:   0.0600
#   vol.soil2latflow:   0.0000
#    vol. soil to gw:   0.0000
#  vol. et from soil:   0.0000
#    final vol. soil:   0.7526
#   vol. soil resid.: 1.3323e-15
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   0.0000
#   vol. from nash:   0.0000
#  final vol. nash:   0.0000
# nash casc resid.: 0.0000e+00
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   0.5415
#        vol to gw:   0.0000
#      vol from gw:   0.5415
# final gw.storage:   0.0000
#     gw. residual: -2.8207e-16
#
# GLOBAL MASS BALANCE
#   initial volume:   1.2342
#     volume input:   0.0638
#    volume output:   0.5556
#     final volume:   0.7424
#         residual: 3.3307e-16
#
# PARTITION MASS BALANCE
#     surface runoff:   0.0141
#       infiltration:   0.0497
#  vol. et from rain:   0.0000
# partition residual: 5.5511e-17
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.0141
#    vol. out giuh:   0.0141
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.6927
#     vol. into soil:   0.0497
#   vol.soil2latflow:   0.0000
#    vol. soil to gw:   0.0000
#  vol. et from soil:   0.0000
#    final vol. soil:   0.7424
#   vol. soil resid.: 3.3307e-16
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   0.0000
#   vol. from nash:   0.0000
#  final vol. nash:   0.0000
# nash casc resid.: 0.0000e+00
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   0.5415
#        vol to gw:   0.0000
#      vol from gw:   0.5415
# final gw.storage:   0.0000
#     gw. residual: -2.8207e-16
#
# GLOBAL MASS BALANCE
#   initial volume:   1.5806
#     volume input:   0.0580
#    volume output:   0.9133
#     final volume:   0.7253
#         residual: -6.6613e-16
#
# PARTITION MASS BALANCE
#     surface runoff:   0.0031
#       infiltration:   0.0549
#  vol. et from rain:   0.0000
# partition residual: -5.5511e-17
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.0031
#    vol. out giuh:   0.0031
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.6702
#     vol. into soil:   0.0549
#   vol.soil2latflow:   0.0000
#    vol. soil to gw:   0.0000
#  vol. et from soil:   0.0000
#    final vol. soil:   0.7251
#   vol. soil resid.: -6.6613e-16
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   0.0000
#   vol. from nash:   0.0000
#  final vol. nash:   0.0000
# nash casc resid.: 0.0000e+00
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   0.9104
#        vol to gw:   0.0000
#      vol from gw:   0.9101
# final gw.storage:   0.0002
#     gw. residual: -3.4469e-16
#
# GLOBAL MASS BALANCE
#   initial volume:   1.1839
#     volume input:   0.0986
#    volume output:   0.7763
#     final volume:   0.5061
#         residual: 1.2212e-15
#
# PARTITION MASS BALANCE
#     surface runoff:   0.0234
#       infiltration:   0.0752
#  vol. et from rain:   0.0000
# partition residual: 2.7756e-17
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.0234
#    vol. out giuh:   0.0234
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.6424
#     vol. into soil:   0.0752
#   vol.soil2latflow:   0.2089
#    vol. soil to gw:   0.0025
#  vol. et from soil:   0.0000
#    final vol. soil:   0.5061
#   vol. soil resid.: -6.6613e-16
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   0.2089
#   vol. from nash:   0.2086
#  final vol. nash:   0.0003
# nash casc resid.: 7.6490e-17
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   0.5415
#        vol to gw:   0.0025
#      vol from gw:   0.5440
# final gw.storage:   0.0000
#     gw. residual: 5.2622e-16
#
# GLOBAL MASS BALANCE
#   initial volume:   0.7935
#     volume input:   0.0893
#    volume output:   0.1994
#     final volume:   0.6834
#         residual: 2.5514e-08
#
# PARTITION MASS BALANCE
#     surface runoff:   0.0101
#       infiltration:   0.0792
#  vol. et from rain:   0.0000
# partition residual: 1.3878e-16
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.0101
#    vol. out giuh:   0.0101
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.6625
#     vol. into soil:   0.0792
#   vol.soil2latflow:   0.0572
#    vol. soil to gw:   0.0011
#  vol. et from soil:   0.0000
#    final vol. soil:   0.6834
#   vol. soil resid.: 2.5514e-08
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   0.0572
#   vol. from nash:   0.0570
#  final vol. nash:   0.0003
# nash casc resid.: -5.0090e-17
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   0.1310
#        vol to gw:   0.0011
#      vol from gw:   0.1321
# final gw.storage:   0.0000
#     gw. residual: -2.3436e-16
#
# GLOBAL MASS BALANCE
#   initial volume:   1.1844
#     volume input:   0.0818
#    volume output:   0.7251
#     final volume:   0.5411
#         residual: 8.8818e-16
#
# PARTITION MASS BALANCE
#     surface runoff:   0.0124
#       infiltration:   0.0694
#  vol. et from rain:   0.0000
# partition residual: -1.6653e-16
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.0124
#    vol. out giuh:   0.0124
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.6428
#     vol. into soil:   0.0694
#   vol.soil2latflow:   0.1682
#    vol. soil to gw:   0.0030
#  vol. et from soil:   0.0000
#    final vol. soil:   0.5410
#   vol. soil resid.: 1.1102e-16
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   0.1682
#   vol. from nash:   0.1677
#  final vol. nash:   0.0006
# nash casc resid.: 1.5873e-16
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   0.5415
#        vol to gw:   0.0030
#      vol from gw:   0.5445
# final gw.storage:   0.0000
#     gw. residual: 4.5802e-16
#
# GLOBAL MASS BALANCE
#   initial volume:   2.2068
#     volume input:   0.0975
#    volume output:   2.0537
#     final volume:   0.2506
#         residual: -4.2188e-15
#
# PARTITION MASS BALANCE
#     surface runoff:   0.0098
#       infiltration:   0.0876
#  vol. et from rain:   0.0000
# partition residual: 8.3267e-17
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.0098
#    vol. out giuh:   0.0098
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.6142
#     vol. into soil:   0.0876
#   vol.soil2latflow:   0.4465
#    vol. soil to gw:   0.0194
#  vol. et from soil:   0.0000
#    final vol. soil:   0.2359
#   vol. soil resid.: -6.1062e-16
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   0.4465
#   vol. from nash:   0.4456
#  final vol. nash:   0.0009
# nash casc resid.: 5.2193e-16
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   1.5926
#        vol to gw:   0.0194
#      vol from gw:   1.5974
# final gw.storage:   0.0147
#     gw. residual: -4.8919e-15
#
# GLOBAL MASS BALANCE
#   initial volume:   1.2327
#     volume input:   0.0536
#    volume output:   0.5564
#     final volume:   0.7298
#         residual: 0.0000e+00
#
# PARTITION MASS BALANCE
#     surface runoff:   0.0149
#       infiltration:   0.0387
#  vol. et from rain:   0.0000
# partition residual: 4.1633e-17
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.0149
#    vol. out giuh:   0.0149
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.6912
#     vol. into soil:   0.0387
#   vol.soil2latflow:   0.0000
#    vol. soil to gw:   0.0000
#  vol. et from soil:   0.0000
#    final vol. soil:   0.7298
#   vol. soil resid.: 0.0000e+00
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   0.0000
#   vol. from nash:   0.0000
#  final vol. nash:   0.0000
# nash casc resid.: 0.0000e+00
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   0.5415
#        vol to gw:   0.0000
#      vol from gw:   0.5415
# final gw.storage:   0.0000
#     gw. residual: -2.8207e-16
#
# GLOBAL MASS BALANCE
#   initial volume:   1.1913
#     volume input:   0.0964
#    volume output:   0.7481
#     final volume:   0.5396
#         residual: 1.5543e-15
#
# PARTITION MASS BALANCE
#     surface runoff:   0.0088
#       infiltration:   0.0876
#  vol. et from rain:   0.0000
# partition residual: 1.2490e-16
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.0088
#    vol. out giuh:   0.0088
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.6498
#     vol. into soil:   0.0876
#   vol.soil2latflow:   0.1905
#    vol. soil to gw:   0.0073
#  vol. et from soil:   0.0000
#    final vol. soil:   0.5396
#   vol. soil resid.: 2.2204e-16
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   0.1905
#   vol. from nash:   0.1899
#  final vol. nash:   0.0006
# nash casc resid.: -7.7564e-16
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   0.5415
#        vol to gw:   0.0073
#      vol from gw:   0.5488
# final gw.storage:   0.0001
#     gw. residual: 1.5030e-15
#
# GLOBAL MASS BALANCE
#   initial volume:   1.1839
#     volume input:   0.1016
#    volume output:   0.8244
#     final volume:   0.4611
#         residual: 5.5511e-17
#
# PARTITION MASS BALANCE
#     surface runoff:   0.0132
#       infiltration:   0.0885
#  vol. et from rain:   0.0000
# partition residual: 1.2490e-16
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.0132
#    vol. out giuh:   0.0132
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.6424
#     vol. into soil:   0.0885
#   vol.soil2latflow:   0.2595
#    vol. soil to gw:   0.0103
#  vol. et from soil:   0.0000
#    final vol. soil:   0.4610
#   vol. soil resid.: 9.9920e-16
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   0.2595
#   vol. from nash:   0.2592
#  final vol. nash:   0.0003
# nash casc resid.: -1.3199e-15
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   0.5415
#        vol to gw:   0.0103
#      vol from gw:   0.5518
# final gw.storage:   0.0001
#     gw. residual: 2.9151e-16

# %% [markdown]
# If you want to visualize the outputs and verify the flows:

# %%
file = pd.read_csv('./wb-2624577_retro_3_2022/outputs/cat-2624940_output.csv')
discharge = file['land_surface_water__runoff_volume_flux']
giuh = file['GIUH_RUNOFF']
lateral = file['NASH_LATERAL_RUNOFF']
gw = file['DEEP_GW_TO_CHANNEL_FLUX']

# %%
file1 = pd.read_csv('./wb-2624577_retro_3_2022/outputs copy/cat-2624940_output.csv')
discharge1 = file1['land_surface_water__runoff_volume_flux']
lateral1 = file1['NASH_LATERAL_RUNOFF']
gw1 = file1['DEEP_GW_TO_CHANNEL_FLUX']

# %%
pip install dataretrieval
# Out:
# Requirement already satisfied: dataretrieval in /opt/conda/lib/python3.9/site-packages (1.0.4)
# Requirement already satisfied: requests in /opt/conda/lib/python3.9/site-packages (from dataretrieval) (2.31.0)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.9/site-packages (from dataretrieval) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.9/site-packages (from pandas->dataretrieval) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.9/site-packages (from pandas->dataretrieval) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.9/site-packages (from pandas->dataretrieval) (2023.3)
# Requirement already satisfied: numpy>=1.20.3 in /opt/conda/lib/python3.9/site-packages (from pandas->dataretrieval) (1.24.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.9/site-packages (from requests->dataretrieval) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.9/site-packages (from requests->dataretrieval) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.9/site-packages (from requests->dataretrieval) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.9/site-packages (from requests->dataretrieval) (2023.5.7)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas->dataretrieval) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import dataretrieval.nwis as nwis
import pandas as pd

discharge_nwis = nwis.get_record(sites="8150800", parameterCd='00060', start="2016-12-01", end="2017-02-28")
discharge_resampled = discharge_nwis.select_dtypes(include=['float64', 'int64']).resample('H').mean() # Hourly averaged value
discharge_dataframe = discharge_resampled

# %%
discharge_usgs1 = discharge_resampled['00060'].values
discharge_usgs = discharge_usgs1/35.315

# %%
# plt.plot(discharge_usgs)
plt.plot(discharge)
plt.plot(discharge1)

# %%
np.sum(discharge)
# Out:
# 293.34574452879286

# %%
# plt.plot(giuh1, color = 'r')
plt.plot(giuh, color = 'g')

# %%
plt.plot(lateral)
plt.plot(lateral1)

# %%
plt.plot(gw)
plt.plot(gw1)
